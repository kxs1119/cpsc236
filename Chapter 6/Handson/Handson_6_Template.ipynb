# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
import csv

def extractdata(file):
    # extracting the data from the text file 
    data = [] # creating an empty list 
    with open(file) as f:
        reader = csv.reader(f)
        for row in reader:
            data.append(row)
        return data

def splitdata(data):
    champions = {}
    for row in data:
        year = row[0]
        country = row[1]
        coach = row[2]
        captain = row[3]
        if country in champions:
            champions[country][0].append(year)
            champions[country][1] += 1
        else:
            champions[country] = [[year], 1]
    return champions

def printData(champions):
    # Print header
    print("Country".ljust(12), "Wins".ljust(7), "Years".ljust(10))
    print("="*30)
    
    # Print data
    for country, (years, wins) in sorted(champions.items()):
        print(country.ljust(12), str(wins).ljust(7), ', '.join(map(str, years)).ljust(10))
        
    



def main():
    data = extractdata('world_cup_champions.txt')
    champions = splitdata(data)
    results = printData(champions)
    print(results)
    

if __name__ == '__main__':
    main()
# Out:
# Country      Wins    Years
# ==============================
# Argentina    2       1978, 1986
# Brazil       5       1958, 1962, 1970, 1994, 2002
# Country      1       Year
# England      1       1966
# France       1       1998
# Germany      4       1954, 1974, 1990, 2014
# Italy        4       1934, 1938, 1982, 2006
# Spain        1       2010
# Uruguay      2       1930, 1950
# None

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 0
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
def view(file, sales, month):
    month_abbreviations = month.lower()
    if month_abbreviations not in sales:
        print("Invalid three-letter month.")
    else:
        print(f"Sales amount for {month_abbreviations} is {sales[month_abbreviations]}.")
def edit(sales, amount, month):
    month_abbreviations = month.lower()
    if month_abbreviations not in sales:
        print("Invalid three-letter month.")
        return
    
def totals(sales,year):
    yearly_total = 0
    monthly_average = 0
    for month in sales:
        yearly_total += sales[month]
    monthly_average = yearly_total / 12
    print(f"Yearly total: {yearly_total:.2f}")
    print(f"Monthly average: {monthly_average:.2f}")
def read(file):
    salesDictionary = {} # declare a dictionary
    with open(file, 'r') as f:
        for line in f:
            line = line.split(',')
            month = line[0] 
            sales = float(line[1]) # convert string to float
            salesDictionary[month] = sales
    return salesDictionary

def write(file, sales):
    with open(file, 'w') as f:
        for month in sales:
            f.write(f"{month},{sales[month]}\n")
        
def main():
    file = 'monthly_sales.txt'
    sales = read(file)
    
    print("Monthly Sales program\n")
    while True:
        print("view - view sales for specified month")
        print("edit - edit sales for specified month")
        print("totals - view sales summary for year")
        print("exit - exit program")
        input = input("Command: ")
        # conditionals statement based on user input
        if input == "view":
            month = input("Three-letter Month: ")
            view(file, sales)
        elif input == "edit":
            month = input("Three-letter Month: ")
            edit(sales, month)
            write(file, sales)
        elif input == "totals":
            totals(sales)
        elif input == "exit":
            print("Bye!")
            break
        else:
            print("Invalid command. Please try again.")
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 63
#      61             print("Invalid command. Please try again.")
#      62 if __name__ == '__main__':
# ---> 63     main()
#
# Cell In[1], line 38, in main()
#      36 def main():
#      37     file = 'monthly_sales.txt'
# ---> 38     sales = read(file)
#      40     print("Monthly Sales program\n")
#      41     while True:
#
# Cell In[1], line 27, in read(file)
#      25         line = line.split(',')
#      26         month = line[0]
# ---> 27         sales = float(line[1]) # convert string to float
#      28         salesDictionary[month] = sales
#      29 return salesDictionary
#
# IndexError: list index out of range
